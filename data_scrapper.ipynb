# %%
# !git clone https://gitlab.lis-lab.fr/bibliovid/scrappers.git
# !pip install -r scrappers/requirements.txt
# Out:
# Cloning into 'scrappers'...
# remote: Enumerating objects: 44, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 44 (delta 23), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (44/44), done.
# ...

# %%
# !bash scrappers/run.sh
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# https://www.ncbi.nlm.nih.gov/research/coronavirus-api/search/?page=4980
# https://www.ncbi.nlm.nih.gov/research/coronavirus-api/search/?page=4981
# https://www.ncbi.nlm.nih.gov/research/coronavirus-api/search/?page=4982
# https://www.ncbi.nlm.nih.gov/research/coronavirus-api/search/?page=4983
# https://www.ncbi.nlm.nih.gov/research/coronavirus-api/search/?page=4984
# https://www.ncbi.nlm.nih.gov/research/coronavirus-api/search/?page=4985
# https://www.ncbi.nlm.nih.gov/research/coronavirus-api/search/?page=4986
# https://www.ncbi.nlm.nih.gov/research/coronavirus-api/search/?page=4987
# https://www.ncbi.nlm.nih.gov/research/coronavirus-api/search/?page=4988
# https://www.ncbi.nlm.nih.gov/research/coronavirus-api/search/?page=4989
# https://www.ncbi.nlm.nih.gov/research/coronavirus-api/search/?page=4990
# https://www.ncbi.nlm.nih.gov/research/coronavirus-api/search/?page=4991
# ...
